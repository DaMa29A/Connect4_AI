# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/Connect4/

# %%
# !pip install colorama stable_baselines3 sb3_contrib

# %%
# !python play_game.py

# %%
# !python ai_training.py

# %%
# !python get_statistics.py
